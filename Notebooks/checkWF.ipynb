# %%
# %matplotlib inline
import tables
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import mplFunctions as mpl

# %% [markdown]
# # Kr waveforms

# %%
h5f =tables.open_file('/home/jmbenlloch/next/IC/data/Kr/dst_NEXT_v0_08_02_Kr_ACTIVE_0_0_5bar_MCRD_10000.root.h5')
pmtrwf = h5f.root.RD.pmtrwf
pmtcwf = h5f.root.RD.pmtcwf

# %%
mpl.scan_waveforms(pmtcwf,list_of_events=[10,50,70,90])
# Out:
# Press a key...
# Press a key...
# Press a key...
# Press a key...

# %%
plt.plot(pmtrwf[50,0])

# %%
plt.plot(pmtcwf[50,0])

# %% [markdown]
# # Na waveforms

# %%
h5f =tables.open_file('/home/jmbenlloch/next/IC/data/Na/dst_NEXT_v0_08_02_Na_SOURCE_PORT_ANODE_0_0_5bar_MCRD_10000.root.h5')
pmtrwf = h5f.root.RD.pmtrwf
pmtcwf = h5f.root.RD.pmtcwf

# %%
mpl.scan_waveforms(pmtcwf,list_of_events=[10,50,70,90])
# Out:
# Press a key...
# Press a key...
# Press a key...
# Press a key...

# %%
plt.plot(pmtrwf[55,0])

# %%
plt.plot(pmtcwf[55,0])

# %% [markdown]
# # Tl waveforms

# %%
h5f =tables.open_file('/home/jmbenlloch/next/IC/data/Tl/dst_NEXT_v0_08_02_Tl_SOURCE_PORT_ANODE_0_0_5bar_MCRD_10000.root.h5')
pmtrwf = h5f.root.RD.pmtrwf
pmtcwf = h5f.root.RD.pmtcwf

# %%
mpl.scan_waveforms(pmtcwf,list_of_events=[10,50,70,90])
# Out:
# Press a key...
# Press a key...
# Press a key...
# Press a key...

# %%
plt.plot(pmtrwf[50,0])

# %%
plt.plot(pmtcwf[50,0])

# %%
plt.plot(pmtrwf[90,0])

# %%
plt.plot(pmtrwf[90,0])
